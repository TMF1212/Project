# %% [markdown]
# ## AIDev dataset

# %%
import pandas as pd
all_pr_df = pd.read_parquet("hf://datasets/hao-li/AIDev/all_pull_request.parquet")
all_repo_df = pd.read_parquet("hf://datasets/hao-li/AIDev/all_repository.parquet")
all_user_df = pd.read_parquet("hf://datasets/hao-li/AIDev/all_user.parquet")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
all_pr_df
# Out:
#                 id  number                                              title  \
# 0       3264016139    1688  `metta code` --> `metta clip` and additional p...
# 1       3264021033      41  feat: Comprehensive ruff error resolution with...
# 2       3264042289    1600  Add Evals frontend implementation plan and HTM...
# 3       3264042318    1601  Add 4 new BfDs components for Evals interface ...
# 4       3264067496       3  🚀 Complete Frontend-Backend API Integration wi...
# ...            ...     ...                                                ...
# 932786  2858495710      79        chore: update RPC endpoint and build target
# 932787  2858498986       6  feat: enhance recruitment management system wi...
# 932788  2858525953      80  fix: revert to PR #73 OpenAI config with updat...
# 932789  2858527610     400          Add Doxygen Documentation for Public APIs
# 932790  2858539698       2   Convert remaining JavaScript files to ES modules
#
# ...

# %%
all_repo_df
# Out:
#                 id                                                url  \
# 0        987641962  https://api.github.com/repos/1010-dev/senjudev...
# 1        990249393  https://api.github.com/repos/106-/HellSinkerWa...
# 2       1009549206  https://api.github.com/repos/1genadam/tileshop...
# 3        983546765  https://api.github.com/repos/1kimnet/ETL-pipeline
# 4       1024190983  https://api.github.com/repos/20m61/lightningta...
# ...            ...                                                ...
# 116206  1020305485  https://api.github.com/repos/zx8086/kong-konne...
# 116207   976509925  https://api.github.com/repos/zx8086/mcp-server...
# 116208   989288917  https://api.github.com/repos/zx8086/mcp-server...
# 116209   915873255        https://api.github.com/repos/zxcpluto/First
# 116210  1000819309  https://api.github.com/repos/zyumax/devin-hand...
#
#            license                        full_name    language  forks  stars
# ...

# %%
all_user_df
# Out:
#                 id          login  followers  following            created_at
# 0      149159513.0     00012122Cs        0.0        0.0  2023-10-27T10:22:50Z
# 1       86906973.0     000Sean000        0.0        2.0  2021-07-04T07:05:40Z
# 2       36679210.0        000alen       46.0      106.0  2018-02-20T21:00:55Z
# 3      201261210.0       000qhrey        0.0        1.0  2025-02-28T16:53:21Z
# 4       22735204.0       00125495        0.0        1.0  2016-10-10T01:24:34Z
# ...            ...            ...        ...        ...                   ...
# 72184  128873850.0       zztime04        0.0        1.0  2023-03-25T01:50:00Z
# 72185   46803451.0  zzy1099207684        0.0        1.0  2019-01-18T02:51:48Z
# 72186   35818234.0      zzzpotato        2.0        0.0  2018-01-25T20:59:53Z
# 72187   55004427.0        zzzsaft        1.0        0.0  2019-09-06T21:50:29Z
# 72188   46273764.0        zzzz465       42.0       71.0  2018-12-31T04:08:21Z
#
# [72189 rows x 5 columns]

# %% [markdown]
# ## AIDev-pop (repositories that have more than 100 stars)

# %%
# Basic
pr_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pull_request.parquet")
repo_df = pd.read_parquet("hf://datasets/hao-li/AIDev/repository.parquet")
user_df = pd.read_parquet("hf://datasets/hao-li/AIDev/user.parquet")

# Comments and reviews
pr_comments_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_comments.parquet")
pr_reviews_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_reviews.parquet")
pr_review_comments_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_review_comments.parquet")

# Commits
pr_commits_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_commits.parquet")
pr_commit_details_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_commit_details.parquet")

# Related issues
related_issue_df = pd.read_parquet("hf://datasets/hao-li/AIDev/related_issue.parquet")
issue_df = pd.read_parquet("hf://datasets/hao-li/AIDev/issue.parquet")

# Events
pr_timeline_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_timeline.parquet")

# Task type
pr_task_type_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_task_type.parquet")

# Human-PR
human_pr_df = pd.read_parquet("hf://datasets/hao-li/AIDev/human_pull_request.parquet")
human_pr_task_type_df = pd.read_parquet("hf://datasets/hao-li/AIDev/human_pr_task_type.parquet")

# %%
print(f"len(pr_df): {len(pr_df)}")
print(f"len(repo_df): {len(repo_df)}")
print(f"len(user_df): {len(user_df)}")

print(f"len(pr_comments_df): {len(pr_comments_df)}")
print(f"len(pr_reviews_df): {len(pr_reviews_df)}")
print(f"len(pr_review_comments_df): {len(pr_review_comments_df)}")

print(f"len(pr_commits_df): {len(pr_commits_df)}")
print(f"len(pr_commit_details_df): {len(pr_commit_details_df)}")


print(f"len(related_issue_df): {len(related_issue_df)}")
print(f"len(issue_df): {len(issue_df)}")

print(f"len(pr_timeline_df): {len(pr_timeline_df)}")

print(f"len(pr_task_type_df): {len(pr_task_type_df)}")

print(f"len(human_pr_df): {len(human_pr_df)}")
print(f"len(human_pr_task_type_df): {len(human_pr_task_type_df)}")
# Out:
# len(pr_df): 33596
# len(repo_df): 2807
# len(user_df): 1796
# len(pr_comments_df): 39122
# len(pr_reviews_df): 28875
# len(pr_review_comments_df): 19450
# len(pr_commits_df): 88576
# len(pr_commit_details_df): 711923
# len(related_issue_df): 4923
# len(issue_df): 4614
# len(pr_timeline_df): 325500
# len(pr_task_type_df): 33596
# len(human_pr_df): 6618
# len(human_pr_task_type_df): 6618

# %% [markdown]
# ### Extract patches from merged Agentic-PRs

# %%
merged_pr_mask = ~pr_df['merged_at'].isna()
merged_pr_ids = pr_df[merged_pr_mask]['id']
patch_mask = pr_commit_details_df['pr_id'].isin(merged_pr_ids)
pr_commit_details_df[patch_mask]['patch'].dropna()
# Out:
# 75        @@ -162,6 +162,10 @@ class AudioRecorderManage...
# 76        @@ -0,0 +1,36 @@\n+/**\n+ * React 19 Compatibl...
# 77        @@ -0,0 +1,21 @@\n+/**\n+ * React 19 Compatibl...
# 78        @@ -1,6 +1,6 @@\n import * as React from "reac...
# 79        @@ -1,7 +1,7 @@\n import * as React from "reac...
#                                 ...
# 711911    @@ -69,6 +69,7 @@\n         "monaco-editor": "...
# 711912    @@ -7,7 +7,6 @@ import { invokeMainChannel } f...
# 711913    @@ -104,15 +104,13 @@ const Terminal = observe...
# 711914    @@ -110,7 +110,7 @@ const Terminal = observer(...
# 711915    @@ -9,7 +9,7 @@\n     },\n     "apps/studio": ...
# Name: patch, Length: 243762, dtype: object

# %% [markdown]
# ### Check PR type

# %%
pr_task_type_df['type'].value_counts()
# Out:
# type
# feat        14450
# fix          8106
# docs         3887
# test         2356
# refactor     2288
# chore         896
# build         627
# ci            411
# perf          340
# style         188
# other          31
# revert         16
# Name: count, dtype: int64

# %%
import pandas as pd

# Identify Agentic PRs
# Assuming 'agent' column exists and contains agent identifiers or usernames
agent_candidates = ['OpenAI Codex', 'Devin', 'GitHub Copilot', 'Cursor', 'Claude Code']
agent_prs = all_pr_df[all_pr_df['agent'].isin(agent_candidates)]

# %%
#  Link PRs with user data to get user creation dates
# Merge PRs with users on user_id
agent_prs_users = agent_prs.merge(all_user_df, left_on='user_id', right_on='id', how='left')

# %%
# Convert relevant date columns to datetime
agent_prs_users['pr_created_at'] = pd.to_datetime(agent_prs_users['created_at_x'])  # PR creation date
agent_prs_users['user_created_at'] = pd.to_datetime(agent_prs_users['created_at_y'])  # User account creation

# %%
# Calculate user experience at the time of PR creation
agent_prs_users['experience_days'] = (agent_prs_users['pr_created_at'] - agent_prs_users['user_created_at']).dt.days

# %%
# Classify developers into newcomers and experienced
# Newcomers: less than 180 days (6 months)
newcomers = agent_prs_users[agent_prs_users['experience_days'] < 180]

# %%
# Experienced: at least 365 days (1 year)
experienced = agent_prs_users[agent_prs_users['experience_days'] >= 365]

# %%
# Step 6: Analyze the adoption pattern
num_newcomers = len(newcomers)
num_experienced = len(experienced)
# Calculate the number of unique users who used agents
num_unique_agent_users = agent_prs_users['user_id'].nunique()

# %%
#  Cross-tabulate by repository or other metadata for ecosystem analysis
# Merge with all_repo_df to get repository names
agent_prs_users_with_repo = agent_prs_users.merge(all_repo_df, left_on='repo_id', right_on='id', how='left')

# group by repository full name
adoption_by_repo = agent_prs_users_with_repo.groupby('full_name')['user_id'].nunique()

# Output results
print(f"Total Agentic PRs analyzed: {len(agent_prs)}")
print(f"Number from newcomers (<6 months): {num_newcomers}")
print(f"Number from experienced developers (>=1 year): {num_experienced}")
print(f"Number of unique users who used agents: {num_unique_agent_users}")
print("\nAdoption by repository (number of unique users who used agents):")
print(adoption_by_repo)
# Out:
# Total Agentic PRs analyzed: 62685
# Number from newcomers (<6 months): 8357
# Number from experienced developers (>=1 year): 49424
# Number of unique users who used agents: 9658
#
# Adoption by repository (number of unique users who used agents):
# full_name
# 000alen/compute               1
# 00125495/repo_datium_etl      1
# 001priyanshi/priyanshi-bot    1
# 001vamp/Midget                1
# 00MATRX/00matrx.github.io     1
#                              ..
# zyumax/devin-hands-on         1
# zyxgene/algorithms            1
# zzeynepcvk/zzeynepcvk         1
# zzoomless7/design             1
# zzzpotato/s-nomp              1
# Name: user_id, Length: 17332, dtype: int64

# %%
total_prs = len(agent_prs)
proportion_newcomers = num_newcomers / total_prs
proportion_experienced = num_experienced / total_prs

print(f"Proportion of agent PRs from newcomers: {proportion_newcomers:.2%}")
print(f"Proportion from experienced developers: {proportion_experienced:.2%}")
# Out:
# Proportion of agent PRs from newcomers: 13.33%
# Proportion from experienced developers: 78.85%

# %%
import matplotlib.pyplot as plt

# Data for pie chart
labels = ["Newcomers (<6 months)", "Experienced (>=1 year)"]
sizes = [num_newcomers, num_experienced]

# Create pie chart
plt.figure(figsize=(6, 6))
plt.pie(
    sizes,
    labels=labels,
    autopct='%1.1f%%',
    startangle=140,
    colors=["#66b3ff", "#99ff99"]
)
plt.title("Adoption of Coding Agents: Newcomers vs Experienced")
plt.show()

# %%
# Count Agentic PRs per repository
adoption_by_repo = all_pr_df.groupby("repo_id")["agent"].apply(lambda x: (x == "Claude_Code").sum())
adoption_by_repo = adoption_by_repo.sort_values(ascending=False)

print("Top repositories by Agentic PR adoption:")
print(adoption_by_repo.head(10))
# Out:
# Top repositories by Agentic PR adoption:
# repo_id
# 9.267118e+08    575
# 1.017722e+09    223
# 1.011263e+09     41
# 1.002780e+09     37
# 9.894399e+08     37
# 1.018763e+09     33
# 1.001156e+09     32
# 9.836513e+08     32
# 9.466508e+08     30
# 7.156839e+08     28
# Name: agent, dtype: int64

# %%
# Total PRs per repo
total_prs_by_repo = all_pr_df.groupby("repo_id")["id"].count()

# Fraction of PRs that are agentic
adoption_fraction = adoption_by_repo / total_prs_by_repo
adoption_fraction = adoption_fraction.sort_values(ascending=False)

print("Repos with highest proportion of Agentic PRs:")
print(adoption_fraction.head(10))
# Out:
# Repos with highest proportion of Agentic PRs:
# repo_id
# 9.714036e+08    1.0
# 8.555720e+08    1.0
# 1.021883e+09    1.0
# 6.225880e+08    1.0
# 1.001691e+09    1.0
# 9.890372e+08    1.0
# 1.003303e+08    1.0
# 1.014550e+09    1.0
# 1.023553e+09    1.0
# 1.010094e+09    1.0
# dtype: float64

# %%
import matplotlib.pyplot as plt

# Plot top 10 repos by proportion
top10_fraction = adoption_fraction.head(10)

plt.figure(figsize=(10, 6))
top10_fraction.plot(kind="bar", color="skyblue")
plt.ylabel("Proportion of Agentic PRs")
plt.title("Top 10 Repositories by Agent Adoption")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
# Extract ecosystem (repo_url format: https://api.github.com/repos/{owner}/{repo})
all_pr_df["ecosystem"] = all_pr_df["repo_url"].apply(lambda x: x.split("/")[-2])

# Count agentic PRs per ecosystem
adoption_by_ecosystem = all_pr_df.groupby("ecosystem")["agent"].apply(lambda x: (x == "Claude_Code").sum())
total_by_ecosystem = all_pr_df.groupby("ecosystem")["id"].count()

# Fraction
ecosystem_fraction = (adoption_by_ecosystem / total_by_ecosystem).sort_values(ascending=False)

print("Ecosystem-level adoption patterns:")
print(ecosystem_fraction.head(10))
# Out:
# Ecosystem-level adoption patterns:
# ecosystem
# Babas10           1.0
# hirorocky         1.0
# johannahaffner    1.0
# atriumn           1.0
# unkeyed           1.0
# wize73-ai         1.0
# ashean            1.0
# joha1na           1.0
# CambrianTech      1.0
# eijun-t           1.0
# dtype: float64

# %%
# Top ecosystems by proportion
top10_ecosystem = ecosystem_fraction.head(10)

plt.figure(figsize=(10, 6))
top10_ecosystem.plot(kind="bar", color="lightgreen")
plt.ylabel("Proportion of Agentic PRs")
plt.title("Top 10 Ecosystems by Agent Adoption")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
# Mark whether PR is agentic (submitted by an AI agent like Claude_Code, Devin, etc.)
all_pr_df["is_agentic"] = all_pr_df["agent"].notnull()

# %%
# PR size = number of characters in body
all_pr_df["pr_size"] = all_pr_df["body"].fillna("").apply(len)

# Compare average PR size
avg_size_agentic = all_pr_df[all_pr_df["is_agentic"]]["pr_size"].mean()
avg_size_human   = all_pr_df[~all_pr_df["is_agentic"]]["pr_size"].mean()

print("Average PR size (chars) - Agentic:", avg_size_agentic)
print("Average PR size (chars) - Human:", avg_size_human)
# Out:
# Average PR size (chars) - Agentic: 529.2423200909957
# Average PR size (chars) - Human: nan

# %%
def classify_task(title):
    title = str(title).lower()
    if "fix" in title or "bug" in title:
        return "bugfix"
    elif "feat" in title or "add" in title or "implement" in title:
        return "feature"
    elif "refactor" in title:
        return "refactor"
    elif "doc" in title or "readme" in title:
        return "docs"
    else:
        return "other"

# Apply task classification
all_pr_df["task_type"] = all_pr_df["title"].apply(classify_task)

# Count distribution
task_counts = all_pr_df.groupby(["task_type", "is_agentic"])["id"].count().unstack(fill_value=0)
print(task_counts)
# Out:
# is_agentic    True
# task_type
# bugfix      219823
# docs         33306
# feature     362763
# other       296648
# refactor     20251

# %%
if "commits" in all_pr_df.columns:
    avg_commits_agentic = all_pr_df[all_pr_df["is_agentic"]]["commits"].mean()
    avg_commits_human   = all_pr_df[~all_pr_df["is_agentic"]]["commits"].mean()

    print("Average commits per PR - Agentic:", avg_commits_agentic)
    print("Average commits per PR - Human:", avg_commits_human)
else:
    print("No 'commits' column found in dataset — skipping commit granularity.")
# Out:
# No 'commits' column found in dataset — skipping commit granularity.

# %%
# Select numeric features
features = ["pr_size"]
if "commits" in all_pr_df.columns:
    features.append("commits")

corr_data = all_pr_df[features + ["is_agentic"]]

# Correlation matrix
print(corr_data.corr())
# Out:
#             pr_size  is_agentic
# pr_size         1.0         NaN
# is_agentic      NaN         NaN

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.boxplot(x="is_agentic", y="pr_size", data=all_pr_df)
plt.xticks([0, 1], ["Human", "Agentic"])
plt.title("PR Size Distribution: Agentic vs Human")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x="task_type", hue="is_agentic", data=all_pr_df)
plt.title("Task Types: Agentic vs Human PRs")
plt.xticks(rotation=30)
plt.show()

# %%
if "commits" in all_pr_df.columns:
    plt.figure(figsize=(8,6))
    sns.boxplot(x="is_agentic", y="commits", data=all_pr_df)
    plt.xticks([0, 1], ["Human", "Agentic"])
    plt.title("Commits per PR: Agentic vs Human")
    plt.show()
